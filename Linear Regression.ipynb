# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Step 1: Sample Data
# X: Hours worked, Y: Salary hike
X = np.array([[1], [2], [3], [4], [5], [6], [7]]) # Feature
y = np.array([1000, 1500, 2000, 2500, 3000, 3200, 3500]) # Target

# %%
# Step 2: Create Model
model = LinearRegression()

# %%
# Step 3: Train Model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Step 4: Predict
y_pred = model.predict(X)

# %%
# Step 5: Print results
print("Coefficient (slope):", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Coefficient (slope): 424.99999999999994
# Intercept: 685.714285714286

# %%
# Step 6: Plot
plt.scatter(X, y, color='blue', label="Actual")
plt.plot(X, y_pred, color='red', label="Predicted Line")
plt.xlabel("Hours Worked")
plt.ylabel("Salary Hike")
plt.title("Linear Regression - Salary vs Hours")
plt.legend()
plt.grid(True)
plt.show()
